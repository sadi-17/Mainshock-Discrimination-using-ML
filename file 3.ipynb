# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/MyDrive/quack RESEARCH/quake_project')
print(sorted(os.listdir())[:30])
# Out:
# Mounted at /content/drive
# ['README.md', 'Untitled0.ipynb', 'build_datasets.py', 'catboost_info', 'chunks', 'comcat_global_m4.meta.json', 'comcat_global_m4.parquet', 'comcat_global_m4_features.parquet', 'comcat_global_m4_labeled.parquet', 'comcat_himalaya_m4.meta.json', 'comcat_himalaya_m4.parquet', 'comcat_himalaya_m4_features.parquet', 'comcat_himalaya_m4_labeled.parquet', 'feat_ckpt', 'figures', 'grid_ckpt', 'label_ckpt', 'labeling_summary.csv', 'models', 'scedc_socal_m25.meta.json', 'scedc_socal_m25.parquet', 'scedc_socal_m25_features.parquet', 'scedc_socal_m25_labeled.parquet', 'step10_transfer.csv', 'step10_transfer.py', 'step11_ablation.csv', 'step11_ablation_stats.py', 'step11_significance.csv', 'step12_baselines.csv', 'step12_baselines.py']

# %%
import shutil, glob, os

# adjust these two lines if the folder landed somewhere else
SRC = '/content/drive/MyDrive/quack RESEARCH/quake_project/pipeline_all_scripts/pipeline'
DST = '/content/drive/MyDrive/quack RESEARCH/quake_project'

# if the upload went to Drive root instead, uncomment:
# SRC = '/content/drive/MyDrive/pipeline_all_scripts/pipeline'

for f in glob.glob(f'{SRC}/*'):
    shutil.move(f, os.path.join(DST, os.path.basename(f)))

os.chdir(DST)
print(sorted(f for f in os.listdir() if f.endswith('.py')))
# Out:
# []

# %%
import subprocess
print(subprocess.run(
    ['find', '/content/drive', '-name', 'comcat_global_m4_features.parquet'],
    capture_output=True, text=True).stdout)
# Out:
# /content/drive/.shortcut-targets-by-id/14OHXJ5fMSvO2BX7B8NCGyNuQZ0FUfVKo/quake_project/comcat_global_m4_features.parquet

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/.shortcut-targets-by-id/14OHXJ5fMSvO2BX7B8NCGyNuQZ0FUfVKo/quake_project')
print(sorted(os.listdir())[:30])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['catboost_info', 'chunks', 'comcat_global_m4.meta.json', 'comcat_global_m4.parquet', 'comcat_global_m4_features.parquet', 'comcat_global_m4_labeled.parquet', 'comcat_himalaya_m4.meta.json', 'comcat_himalaya_m4.parquet', 'comcat_himalaya_m4_features.parquet', 'comcat_himalaya_m4_labeled.parquet', 'feat_ckpt', 'figures', 'grid_ckpt', 'label_ckpt', 'labeling_summary.csv', 'models', 'scedc_socal_m25.meta.json', 'scedc_socal_m25.parquet', 'scedc_socal_m25_features.parquet', 'scedc_socal_m25_labeled.parquet', 'step10_transfer.csv', 'step11_ablation.csv', 'step11_significance.csv', 'step5_metrics.csv', 'step6_aci_rolling.csv', 'step6_calibration.csv', 'step6_conformal.csv', 'step6_reliability_data.csv', 'step7_sensitivity_grid.csv', 'step7_shap_rankings.csv']

# %%
import subprocess, shutil, glob, os
hit = subprocess.run(['find', '/content/drive', '-name', 'step12_baselines.py'],
                     capture_output=True, text=True).stdout.strip().split('\n')[0]
print("scripts found at:", hit)

src_dir = os.path.dirname(hit)
for f in glob.glob(f'{src_dir}/*'):
    shutil.move(f, os.path.basename(f))
print(sorted(f for f in os.listdir() if f.endswith('.py')))
# Out:
# scripts found at: /content/drive/MyDrive/quack RESEARCH/pipeline_all_scripts/pipeline/step12_baselines.py
# ['build_datasets.py', 'step10_transfer.py', 'step11_ablation_stats.py', 'step12_baselines.py', 'step2_himalaya_subset.py', 'step2a_scedc_download.py', 'step3_labeling.py', 'step4_features.py', 'step5_training.py', 'step6_conformal.py', 'step7_sensitivity.py', 'step8_decision.py', 'step9_figures.py']

# %%
# !python step12_baselines.py
# Out:
#   comcat_global_m4 | B1 rate (-local_count_7d): AUC 0.7999 (model 0.9547, p=0.00e+00)
#   comcat_global_m4 | B2 gap (time_gap_local): AUC 0.8749 (model 0.9547, p=0.00e+00)
#   comcat_global_m4 | B3 rate+gap logistic: AUC 0.8836 (model 0.9547, p=0.00e+00)
#   comcat_global_m4 | B4 magdiff heuristic: AUC 0.9108 (model 0.9547, p=0.00e+00)
#   scedc_socal_m25 | B1 rate (-local_count_7d): AUC 0.8615 (model 0.9780, p=0.00e+00)
#   scedc_socal_m25 | B2 gap (time_gap_local): AUC 0.9146 (model 0.9780, p=3.67e-119)
#   scedc_socal_m25 | B3 rate+gap logistic: AUC 0.9276 (model 0.9780, p=4.06e-132)
#   scedc_socal_m25 | B4 magdiff heuristic: AUC 0.9398 (model 0.9780, p=2.61e-148)
#   comcat_himalaya_m4 | B1 rate (-local_count_7d): AUC 0.8059 (model 0.9378, p=1.27e-21)
#   comcat_himalaya_m4 | B2 gap (time_gap_local): AUC 0.8906 (model 0.9378, p=1.49e-05)
#   comcat_himalaya_m4 | B3 rate+gap logistic: AUC 0.8957 (model 0.9378, p=5.14e-05)
#   comcat_himalaya_m4 | B4 magdiff heuristic: AUC 0.9056 (model 0.9378, p=1.12e-04)
#
# === step12_baselines.csv ===
#            catalog                  baseline  auc_baseline  auc_model  delta_auc      delong_p  f1_baseline
#   comcat_global_m4 B1 rate (-local_count_7d)        0.7999     0.9547     0.1548  0.000000e+00       0.7511
#   comcat_global_m4   B2 gap (time_gap_local)        0.8749     0.9547     0.0797  0.000000e+00       0.7644
#   comcat_global_m4      B3 rate+gap logistic        0.8836     0.9547     0.0711  0.000000e+00       0.7695
#   comcat_global_m4      B4 magdiff heuristic        0.9108     0.9547     0.0438  0.000000e+00       0.8888
#    scedc_socal_m25 B1 rate (-local_count_7d)        0.8615     0.9780     0.1165  0.000000e+00       0.7101
#    scedc_socal_m25   B2 gap (time_gap_local)        0.9146     0.9780     0.0634 3.666883e-119       0.7143
#    scedc_socal_m25      B3 rate+gap logistic        0.9276     0.9780     0.0504 4.061552e-132       0.8096
#    scedc_socal_m25      B4 magdiff heuristic        0.9398     0.9780     0.0382 2.607266e-148       0.8890
# comcat_himalaya_m4 B1 rate (-local_count_7d)        0.8059     0.9378     0.1319  1.267338e-21       0.8575
# comcat_himalaya_m4   B2 gap (time_gap_local)        0.8906     0.9378     0.0473  1.489136e-05       0.8260
# comcat_himalaya_m4      B3 rate+gap logistic        0.8957     0.9378     0.0421  5.142694e-05       0.8575
# comcat_himalaya_m4      B4 magdiff heuristic        0.9056     0.9378     0.0323  1.115616e-04       0.9393
